# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_cleand = pd.read_csv("titanic_train_cleaned.csv")
test_cleand = pd.read_csv("titanic_test_cleaned.csv")
train = train_cleand.copy()
test = test_cleand.copy()

# %%
print("Train dataset:")
display(train.head())

print("Test dataset:")
display(test.head())
# Out:
# Train dataset:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_Q  Embarked_S
# 0         0       3    0  22.0      1      0   7.2500       False        True
# 1         1       1    1  38.0      1      0  71.2833       False       False
# 2         1       3    1  26.0      0      0   7.9250       False        True
# 3         1       1    1  35.0      1      0  53.1000       False        True
# 4         0       3    0  35.0      0      0   8.0500       False        True
# Test dataset:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_Q  Embarked_S
# 0       3    0  34.5      0      0   7.8292        True       False
# 1       3    1  47.0      1      0   7.0000       False        True
# 2       2    0  62.0      0      0   9.6875        True       False
# 3       3    0  27.0      0      0   8.6625       False        True
# 4       3    1  22.0      1      1  12.2875       False        True

# %%
print("Train dataset:\n")
display(train.info())

print("\nTest dataset:\n")
display(test.info())
# Out:
# Train dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Sex         891 non-null    int64
#  3   Age         891 non-null    float64
#  4   SibSp       891 non-null    int64
#  5   Parch       891 non-null    int64
#  6   Fare        891 non-null    float64
#  7   Embarked_Q  891 non-null    bool
#  8   Embarked_S  891 non-null    bool
# dtypes: bool(2), float64(2), int64(5)
# memory usage: 50.6 KB
# None
# Test dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pclass      417 non-null    int64
#  1   Sex         417 non-null    int64
#  2   Age         417 non-null    float64
# ...

# %%
print("Train dataset:\n")
display(train.describe())

print("\nTest dataset:\n")
display(test.describe())
# Out:
# Train dataset:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.352413   29.361582    0.523008    0.381594
# std      0.486592    0.836071    0.477990   13.019697    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    0.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200
# Test dataset:
# ...

# %%
print("Train dataset:")
display(train.columns)

print("\nTest dataset:")
display(test.columns)
# Out:
# Train dataset:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked_Q', 'Embarked_S'],
#       dtype='object')
# Test dataset:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
sns.pairplot(train[['Age','Fare','Pclass','SibSp','Parch','Survived']], hue='Survived')
plt.show()

# %%
sns.histplot(train['Fare'], kde=True)
plt.title("Distribution of Fare")
plt.show()

# %%
sns.histplot(train['Age'], kde=True)
plt.title("Distribution of Age")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(train.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
X = train[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked_Q','Embarked_S']]

y = train['Survived']

# %%
print(X.head())
print(y.head(), "\n")

print(X_test.head())
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_Q  Embarked_S
# 0       3    0  22.0      1      0   7.2500       False        True
# 1       1    1  38.0      1      0  71.2833       False       False
# 2       3    1  26.0      0      0   7.9250       False        True
# 3       1    1  35.0      1      0  53.1000       False        True
# 4       3    0  35.0      0      0   8.0500       False        True
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64
#
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_Q  Embarked_S
# 0       3    0  34.5      0      0   7.8292        True       False
# 1       3    1  47.0      1      0   7.0000       False        True
# 2       2    0  62.0      0      0   9.6875        True       False
# 3       3    0  27.0      0      0   8.6625       False        True
# 4       3    1  22.0      1      1  12.2875       False        True

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.4, random_state=101
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)

# Linear Regression was applied to estimate the probability of passenger survival 
#based on the available features.
# Out:
# LinearRegression()

# %%
print(model.intercept_)
# Out:
# 0.8155752658050119

# %%
coeff_df = pd.DataFrame(model.coef_, X_train.columns, columns=['Coefficient'])
coeff_df
# Out:
#             Coefficient
# Pclass        -0.162571
# Sex            0.470612
# Age           -0.005764
# SibSp         -0.036316
# Parch         -0.020666
# Fare           0.000802
# Embarked_Q    -0.023355
# Embarked_S    -0.092099

# %% [markdown]
# coefficient table shows how these features affect survival prediction.

# %%
predictions = model.predict(X_test)

# %%
plt.scatter(y_test, predictions)
plt.xlabel("Actual Survival")
plt.ylabel("Predicted Survival")
plt.title("Actual vs Predicted Survival")
plt.show()

# %%
sns.histplot((y_test - predictions), bins=50, kde=True)
plt.title("Residual Histogram")
plt.xlabel("Error")
plt.show()

# %%
from sklearn import metrics
import numpy as np

print("MAE:", metrics.mean_absolute_error(y_test, predictions))
print("MSE:", metrics.mean_squared_error(y_test, predictions))
print("RMSE:", np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.29430025293698003
# MSE: 0.14571382256037976
# RMSE: 0.3817247995092535
